# %%
import time

# %%
start_time = time.time()

# %%
elapsed = time.time() - start_time

# %%
b_e = [00:00:00, 00:00:24]
# Out:
#   Cell In[11], line 1
#     b_e = [00:00:00, 00:00:24]
#              ^
# SyntaxError: invalid syntax

# %%
import yt_dlp
ydl = yt_dlp.YoutubeDL({})
video_info = ydl.extract_info('https://www.youtube.com/watch?v=dLk9pzmaFHY', download=False)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dLk9pzmaFHY
# [youtube] dLk9pzmaFHY: Downloading webpage
# [youtube] dLk9pzmaFHY: Downloading ios player API JSON
# [youtube] dLk9pzmaFHY: Downloading android player API JSON
# [youtube] dLk9pzmaFHY: Downloading m3u8 information

# %%
video_info.get('duration_string').split(':')
# Out:
# ['4', '34']

# %%
from datetime import time


btime = time(hour=int(0), minute=int(0), second=int(0))
vidTime = time(hour=int(0), minute=int(0), second=int(45))
print(vidTime, btime)
def get_len_seconds(t_one, t_two):
    """Convert a datetime.time object to seconds since midnight."""
    t_one_seconds =  t_one.hour * 3600 + t_one.minute * 60 + t_one.second
    t_two_seconds =  t_two.hour * 3600 + t_two.minute * 60 + t_two.second
    return t_one_seconds - t_two_seconds
get_len_seconds(vidTime, btime)
# Out:
# 00:00:45 00:00:00
# 45

# %%
6/55
# Out:
# 0.10909090909090909

# %%
if elapsed % 1 == 0: 
    print(elapsed)
